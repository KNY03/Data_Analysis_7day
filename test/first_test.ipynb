# %% [markdown]
# # 마크 다운을 활용하는 방법
# # 큰 제목 (#)
# ## 중간 제목 (##)
# ### 작은 제목(###)
# #### (#)을 얼마냐 쓰냐애 따라 크기가 정해진다.
#
# 1개에서 5개 정도로 사용한다

# %% [markdown]
# 기본적으로는
# 줄바꿈 없이
# 공백으로
# 처리된다

# %% [markdown]
# 줄바꿈을
#
# 2번하면 줄바꿈이 된다

# %% [markdown]
# ------------------------------
# - 이런게
#   - 사용하면
#       - 글 앞에
#   - 표 시가
# - 된다

# %% [markdown]
# ----------------------
# 1) 이런 방식으로도 사용가능하다
# 2) 이런 방식으로도 사용가능하다
#    1) 다시 들여쓰는 경우도 가능하다
#    2) 다시 들여쓰는 경우도 가능하다

# %% [markdown]
# ----------------------

# %% [markdown]
# 사진 주소를 넣으면 이미지도 삽입이 된다
#
#
# ![image.png](attachment:c0fac63e-8116-4b91-a2cd-2a2c64be1db1.png)
#
# ![image.png](attachment:d8117a0d-db95-44e0-91e8-e640282b80a9.png)

# %%
print("안녕 주피터 노트북")
# Out:
# 안녕 주피터 노트북
