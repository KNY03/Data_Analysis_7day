# %% [markdown]
# # 제목을 표현할때에는 (#)을 사용
# ## 중간 크기의 제목(##)
# ### 작은 크기의 제목(###)
# #### (#)을 얼마냐 쓰냐애 따라 크기가 정해진다.
#
# 1개에서 5개 정도로 사용한다

# %% [markdown]
# 기본적으로는
# 줄바꿈 없이
# 공백으로
# 처리된다

# %% [markdown]
# 줄바꿈을
#
# 2번하면 줄바꿈이 된다

# %% [markdown]
# ------------------------------
# - 이런게
#   - 사용하면
#       - 글 앞에
#   - 표 시가
# - 된다

# %% [markdown]
# ----------------------
# 1) 이런 방식으로도 사용가능하다
# 2) 이런 방식으로도 사용가능하다

# %%
print("안녕 주피터 노트북")
# Out:
# 안녕 주피터 노트북
